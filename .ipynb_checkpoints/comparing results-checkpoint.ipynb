# %%
import numpy as np
import os
import pandas as pds
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Funciones auxiliares #

# %%
def getData(policy, metric, wsize, scenario, arms, stop_criteria):
    expected_rewards = {'conversion_rate_two_arms': [0.05, 0.04], 
                        'navigation_time_two_arms': [0.15, 0.135],
                        'conversion_rate_many_arms': [0.05, 0.045, 0.04, 0.04, 0.035, 0.035, 0.03, 0.03, 0.02, 0.02], 
                        'navigation_time_many_arms': [0.15, 0.135, 0.135, 0.135, 0.135, 0.135, 0.135, 0.135, 0.135, 0.135]}
    
    if metric == 'regret_from_pulls':
        pulls_data = np.load('data/'  + policy + '-' + scenario + '_' + arms + '_' + 'wsize' + wsize + '_seed_1_low_traffic_nbPulls_' + stop_criteria + '.npy')
        rewards = np.array(expected_rewards[scenario + '_' + arms])
        rewards_diff = rewards[0] - rewards
        regrets_data = np.sum(pulls_data[:,1:]*rewards_diff[1:],1)
        return regrets_data
    else:
        data = np.load('data/'  + policy + '-' + scenario + '_' + arms + '_' + 'wsize' + wsize + '_seed_1_low_traffic_' + metric + '_' + stop_criteria + '.npy')
        return data

# %%
def get_table_summary(metric, scenario, arms, stop_criteria):
    regrets_scenario1_rem_value = pds.DataFrame(index=np.arange(500))
    policies = {'Test AB': ['TestAB_500', '0'],
                'PM wsize = 1': ['ProbabilityMatching_500', '1'],
                'PM wsize = 12': ['ProbabilityMatching_500', '12'],
                'Egreedy': ['Egreedy_500', '1'],
                'TS': ['PossibilisticReward_chernoff2_500', '0']}
    
    if scenario == 'navigation_time':
        policies['PR2'] = policies.pop('TS')
        policies['PR3'] = ['PossibilisticReward_Bern1_500','0']
        
    for k,v in policies.iteritems():
        regrets_scenario1_rem_value[k] = pds.DataFrame(getData(v[0], metric, v[1], scenario, arms, stop_criteria))
    
    return regrets_scenario1_rem_value

# %%
def generate_latex_table(dataframe, round_digits):

    res_descripcion = dataframe.describe().round(round_digits).drop('count')
    res_descripcion_latex = res_descripcion.to_latex(encoding='utf-8')
    print(res_descripcion_latex)

# %%
def generate_graphics(dataframe, clasic):
    dataframe_desc = dataframe.describe()
    res_melted = pds.melt(dataframe, var_name='method', value_name='regret')
    num_policies = len(dataframe.columns)
    
    plt.figure(figsize=(12,12))
    sns.set_style("darkgrid")
    res_melted2 = res_melted.append(['PM wsize = 12', 0.0])
    res_melted2['huecol'] = -999
    res_melted2['huecol'].iloc[-1] = 0.0

    sns.set_palette(my_pal)
    sns.violinplot( x=res_melted2["regret"], 
                   y=res_melted2["method"], 
                   hue=res_melted2['huecol'], 
                   split=True, cut=0, 
                   linewidth=0.5, 
                   color='#F4A460',
                   inner='quartile')


    #plt.xlim(-2, clasic + 0.1*clasic)
    for i in range(num_policies):
        plt.plot((np.zeros(num_policies) + dataframe_desc.iloc[1, i]), np.linspace(i - 0.1 ,i , num_policies), color='red', linewidth=1, linestyle=":")

    best_policy = np.argmin([dataframe_desc.iloc[1, i] for i in range(num_policies)])
    plt.plot((np.zeros(num_policies) + dataframe_desc.iloc[1, best_policy]), np.linspace(-0.4 , num_policies - 0.75 , num_policies), color='violet', linewidth=2, linestyle=":")
    plt.plot((np.zeros(num_policies) + dataframe_desc.iloc[1, best_policy]), np.linspace(best_policy - 0.1 , best_policy, num_policies), color='red', linewidth=2)

    plt.plot((np.zeros(num_policies) + clasic), np.linspace(-0.4 , num_policies - 0.75 , num_policies), color='grey', linewidth=2, linestyle=":")
    plt.legend().remove()
    plt.annotate('best method: ' +  str(round(dataframe_desc.iloc[1, best_policy],2)), [dataframe_desc.iloc[2, best_policy] + 2.1, - 0.45], fontsize=14)
    plt.annotate('stand. test: ' +  str(round(clasic,2)), [clasic - 1.5, num_policies - 0.6], fontsize=14)
    sns.despine()
    plt.xlabel("Regret",fontsize=24)
    plt.ylabel('')
    plt.tick_params(labelsize=22)
    plt.savefig("output.png", bbox_inches = 'tight')

# %%
def generate_table_and_graphic(metric, scenario, arms, stop_criteria, round_digits=3):
    regrets_sampling_beta = get_table_summary(metric, scenario, arms, stop_criteria)
    clasic = {'conversion_rate_two_arms_last_regrets': 11165*(0.05-0.045),
             'conversion_rate_many_arms_last_regrets': 70641*9*(0.05-0.045),
             'navigation_time_two_arms_last_regrets': 14114*(0.15-0.135),
             'navigation_time_many_arms_last_regrets': 21198*9*(0.15-0.135),
             'conversion_rate_two_arms_num_events': 11165,
             'conversion_rate_many_arms_num_events': 70641*10,
             'navigation_time_two_arms_num_events': 14114*2,
             'navigation_time_many_arms_num_events': 21198*10}
    
    f = lambda x: round(x,2)
    generate_latex_table(regrets_sampling_beta, round_digits)
    generate_graphics(regrets_sampling_beta, clasic[scenario + '_' + arms + '_' + metric])

# %%
def get_false_positives(scenario, arms, stop_criteria):
    
        frame = pds.DataFrame(index=np.arange(500))
        policies = {'Test AB': ['TestAB_500', '0'],
                    'PM wsize = 1': ['ProbabilityMatching_500', '1'],
                    'PM wsize = 12': ['ProbabilityMatching_500', '12'],
                    'Egreedy': ['Egreedy_500', '1'],
                    'TS': ['PossibilisticReward_chernoff2_500', '0']}
    
        if scenario == 'navigation_time':
            policies['PR2'] = policies.pop('TS')
            policies['PR3'] = ['PossibilisticReward_Bern1_500','0']
                
        for k,v in policies.iteritems():
            means = np.load('data/'  + v[0] + '-' + scenario + '_' + arms + '_' + 'wsize' + v[1] + '_seed_1_low_traffic_last_means_' + stop_criteria + '.npy')
            true_pos = np.array([all([mean[0] >= i for i in mean]) for mean in means])
            frame[k] = pds.DataFrame(true_pos)

        
        desc= frame.describe()
        desc2 = desc.append(desc.iloc[0] - desc.iloc[3], ignore_index=True)
        desc3 = desc2.append(desc2.iloc[4]/desc2.iloc[0]*100, ignore_index=True)
        desc4 = desc3.drop([1, 2, 3])
        desc5 = desc4.rename({4: 'errors', 0: 'total', 5:'% errors'}, axis='index')
        return desc5

# %%
def sort_all_solutions(scenario, arms):
    criteria = ['sampling_beta', 'pr2']
    if scenario == 'navigation_time':
        criteria += ['sampling_beta_PR3', 'pr3']
    
    frame = get_table_summary('last_regrets', scenario, arms, criteria[0])
    frame_sum = frame.describe()
    
    frame_sum.columns = [name + "--" + criteria[0] for name in frame_sum.columns.values]
    frame_sum_transpose = frame_sum.transpose()
    stop_criteria_alias = {'sampling_beta_conversion_rate':'Bern. value rem.',
                           'sampling_beta_navigation_time':'PR2 value rem.',
                           'sampling_beta_PR3_navigation_time':'PR3 value rem.',
                           'pr2_conversion_rate': 'PR2 bounds',
                           'pr2_navigation_time': 'PR2 bounds',
                           'pr3_navigation_time': 'PR3 bounds'}
    for c in criteria[1:]:
            f = get_table_summary('last_regrets', scenario, arms, c)
            f_sum = f.describe()
            f_sum.columns = [name + "--" + c for name in f_sum.columns.values]
            f_sum_transpose = f_sum.transpose()
            frame_sum_transpose = frame_sum_transpose.append(f_sum_transpose)
    
    stop_cr = [stop_criteria_alias[row.split('--')[1] + '_' + scenario] for row in frame_sum_transpose.index]
    frame_sum_transpose['stop criteria'] = stop_cr
    
    frame_sum_transpose.index = [row.split('--')[0] for row in frame_sum_transpose.index]
    return frame_sum_transpose.sort_values('mean')[['stop criteria','mean','std']]

# %%
def sort_all_by_num_events(scenario, arms):
    criteria = ['sampling_beta', 'pr2']
    if scenario == 'navigation_time':
        criteria += ['sampling_beta_PR3', 'pr3']
    
    frame = get_table_summary('num_events', scenario, arms, criteria[0])
    frame_sum = frame.describe()
    
    frame_sum.columns = [name + "--" + criteria[0] for name in frame_sum.columns.values]
    frame_sum_transpose = frame_sum.transpose()
    stop_criteria_alias = {'sampling_beta_conversion_rate':'Bern. value rem.',
                           'sampling_beta_navigation_time':'PR2 value rem.',
                           'sampling_beta_PR3_navigation_time':'PR3 value rem.',
                           'pr2_conversion_rate': 'PR2 bounds',
                           'pr2_navigation_time': 'PR2 bounds',
                           'pr3_navigation_time': 'PR3 bounds'}
    for c in criteria[1:]:
            f = get_table_summary('num_events', scenario, arms, c)
            f_sum = f.describe()
            f_sum.columns = [name + "--" + c for name in f_sum.columns.values]
            f_sum_transpose = f_sum.transpose()
            frame_sum_transpose = frame_sum_transpose.append(f_sum_transpose)
    
    stop_cr = [stop_criteria_alias[row.split('--')[1] + '_' + scenario] for row in frame_sum_transpose.index]
    frame_sum_transpose['stop criteria'] = stop_cr
    
    frame_sum_transpose.index = [row.split('--')[0] for row in frame_sum_transpose.index]
    return frame_sum_transpose.sort_values('mean')[['stop criteria','mean','std']]

# %%
def sort_false_positives(scenario, arms):    
    criteria = ['sampling_beta', 'pr2']
    if scenario == 'navigation_time':
        criteria += ['sampling_beta_PR3', 'pr3']
    
    frame = get_false_positives(scenario, arms, criteria[0])
    frame_sum = frame
    
    frame_sum.columns = [name + "--" + criteria[0] for name in frame_sum.columns.values]
    frame_sum_transpose = frame_sum.transpose()
    stop_criteria_alias = {'sampling_beta_conversion_rate':'Bern. value rem.',
                           'sampling_beta_navigation_time':'PR2 value rem.',
                           'sampling_beta_PR3_navigation_time':'PR3 value rem.',
                           'pr2_conversion_rate': 'PR2 bounds',
                           'pr2_navigation_time': 'PR2 bounds',
                           'pr3_navigation_time': 'PR3 bounds'}
    for c in criteria[1:]:
            f = get_false_positives(scenario, arms, c)
            f_sum = f
            f_sum.columns = [name + "--" + c for name in f_sum.columns.values]
            f_sum_transpose = f_sum.transpose()
            frame_sum_transpose = frame_sum_transpose.append(f_sum_transpose)
    
    stop_cr = [stop_criteria_alias[row.split('--')[1] + '_' + scenario] for row in frame_sum_transpose.index]
    frame_sum_transpose['stop criteria'] = stop_cr
    
    frame_sum_transpose.index = [row.split('--')[0] for row in frame_sum_transpose.index]
    return frame_sum_transpose

# %%
def show_graph_2(dataframe, clasic):
    num_policies = len(dataframe.columns)
    sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})
    dataframe_desc = dataframe.describe()
    res_melted = pds.melt(dataframe, var_name='method', value_name='regret')
    df = res_melted
    pal = sns.cubehelix_palette(10, rot=-.25, light=.7)
    g = sns.FacetGrid(df, row="method", hue="method", aspect=10, height=1.2, palette=pal)

    # Draw the densities in a few steps
    g.map(sns.kdeplot, "regret", clip_on=False, shade=True, alpha=1, lw=1.5, bw=.2)
    g.map(sns.kdeplot, "regret", clip_on=False, color="w", lw=2, bw=.2)
    g.map(plt.axhline, y=0, lw=2, clip_on=False)
   
    

    # Define and use a simple function to label the plot in axes coordinates
    def label(x, color, label):
        ax = plt.gca()
        ax.text(-0.3, .2, label, fontweight="bold", color=color, fontsize=16,
            ha="left", va="center", transform=ax.transAxes)


    g.map(label, "regret")

    # Set the subplots to overlap
   
    
    best_policy = np.min([dataframe_desc.iloc[1, i] for i in range(num_policies)])
    #plt.plot((np.zeros(num_policies) + dataframe_desc.iloc[1, best_policy]), np.linspace(-0.4 , num_policies - 0.75 , num_policies), color='violet', linewidth=2, linestyle=":")
    #plt.plot((np.zeros(num_policies) + dataframe_desc.iloc[1, best_policy]), np.linspace(best_policy - 0.1 , best_policy, num_policies), color='red', linewidth=2)

    #plt.plot((np.zeros(num_policies) + clasic), np.linspace(-0.4 , num_policies - 0.75 , num_policies), color='grey', linewidth=2, linestyle=":")
    #plt.legend().remove()
    #plt.annotate('best method: ' +  str(round(dataframe_desc.iloc[1, best_policy],2)), [dataframe_desc.iloc[2, best_policy] + 2.1, - 0.45], fontsize=14)
    #plt.annotate('stand. test: ' +  str(round(clasic,2)), [clasic - 1.5, num_policies - 0.6], fontsize=14)
    
    
    # Remove axes details that don't play well with overlap

    g.map(plt.axvline, x=best_policy, lw=2, clip_on=False, color='r', linestyle='--')
    g.map(plt.axvline, x=clasic, lw=2, clip_on=False, color='b', linestyle='--')
    
    def vertical_mean_line_survived(x, **kwargs):
        plt.axvline(x.mean(), lw=2, linestyle = '--', color = 'black', ymax=0.3)
    
    g.map(vertical_mean_line_survived, 'regret')
    
    g.axes[0,0].annotate(round(best_policy, 2) , [best_policy + clasic/50 , plt.ylim()[1]/2])
    g.axes[-1,0].annotate(clasic, [clasic + clasic/50 , plt.ylim()[1]/2])
   
    g.fig.subplots_adjust(hspace=-.15)
    g.set_titles("")
    g.set(yticks=[])
    
    g.despine(bottom=True, left=True)
    plt.savefig("output.png", bbox_inches = 'tight')

# %%
def get_summary(scenario, arms, num):
    data1 = sort_all_solutions(scenario, arms).iloc[:num]
    data2 = sort_all_solutions(scenario, arms).loc['Test AB'].iloc[0]
    data3 = data1.append(data2)
    data4 = sort_all_by_num_events(scenario, arms)
    events = []

    for idx, row in data3.iterrows():
        temp = data4.loc[idx]
        criteria = row['stop criteria']
        events += [temp[temp['stop criteria'] == criteria]['mean'][0]]
    data3['num events mean'] = events
    
    data5 = sort_false_positives(scenario, arms)
    
    events = []
    for idx, row in data3.iterrows():
        temp = data5.loc[idx]
        criteria = row['stop criteria']
        events += [temp[temp['stop criteria'] == criteria]['% errors'][0]]
        
    data3['% errors'] = events
    data3 = data3.rename(columns={'mean': 'regret mean', 'std': 'regret std'})
    print(data3.to_latex(encoding='utf-8'))
    stop_criteria_alias = {'Bern. value rem.': 'sampling_beta',
                           'PR2 value rem.': 'sampling_beta',
                           'PR3 value rem.': 'sampling_beta_PR3',
                           'PR2 bounds': 'pr2',
                           'PR3 bounds': 'pr3'}
                                    
    clasic = {'conversion_rate_two_arms_last_regrets': 11165*(0.05-0.045),
             'conversion_rate_many_arms_last_regrets': 70641*9*(0.05-0.045),
             'navigation_time_two_arms_last_regrets': 14114*(0.15-0.135),
             'navigation_time_many_arms_last_regrets': 21198*9*(0.15-0.135),
             'conversion_rate_two_arms_num_events': 11165,
             'conversion_rate_many_arms_num_events': 70641*10,
             'navigation_time_two_arms_num_events': 14114*2,
             'navigation_time_many_arms_num_events': 21198*10}
    
    detail_data = pds.DataFrame(index=np.arange(500))
    for idx, row in data3.iterrows():
        criteria = row['stop criteria']
        criteria_file = stop_criteria_alias[criteria]
        table = get_table_summary('last_regrets', scenario, arms, criteria_file)
        detail_data[idx + ' | ' + criteria] = table[idx]
        
    #generate_graphics(detail_data, clasic[scenario + '_' + arms + '_' + 'last_regrets'])
    show_graph_2(detail_data, clasic[scenario + '_' + arms + '_' + 'last_regrets'])

# %% [markdown]
# # Escenario 1: conversation time, two arms #

# %% [markdown]
# ## Sumary ##

# %%
get_summary('converion_rate', 'two_arms', 3)
# Out:
#           stop criteria  regret mean  regret std  num events mean  % errors
# PR3          PR3 bounds   297.884755   72.733531         58374.62       0.0
# PR3      PR3 value rem.   314.401856   65.791726         71610.50       0.0
# PR2          PR3 bounds   331.952420   84.501561         47568.54       0.0
# Test AB  PR3 value rem.   683.776872  285.546857         50443.04       0.0

# %% [markdown]
# * regrets - Bernoulli remaining value stop criteria

# %%
generate_table_and_graphic('last_regrets', 'conversion_rate', 'two_arms', 'sampling_beta', 2)
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Test AB &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &     TS \\
# \midrule
# mean &    13.43 &          12.65 &         10.50 &    25.58 &  11.49 \\
# std  &    18.94 &          14.63 &         13.52 &    19.31 &  14.44 \\
# min  &     0.23 &           0.96 &          0.15 &    10.63 &   0.27 \\
# 25\%  &     1.75 &           2.76 &          1.79 &    14.15 &   1.98 \\
# 50\%  &     5.71 &           6.82 &          5.30 &    16.28 &   6.15 \\
# 75\%  &    18.82 &          16.61 &         13.14 &    30.61 &  15.49 \\
# max  &   125.41 &         111.91 &         88.94 &   125.58 &  97.81 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * num. events - Bernoulli remaining value. Stop criteria

# %%
generate_table_and_graphic('num_events', 'conversion_rate', 'two_arms', 'sampling_beta', 0)
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Test AB &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &       TS \\
# \midrule
# mean &   2682.0 &         4263.0 &        3432.0 &   5112.0 &   3873.0 \\
# std  &   3783.0 &         4644.0 &        4159.0 &   3857.0 &   4679.0 \\
# min  &     50.0 &          250.0 &          50.0 &   2100.0 &    100.0 \\
# 25\%  &    350.0 &         1012.0 &         650.0 &   2800.0 &    750.0 \\
# 50\%  &   1150.0 &         2550.0 &        1875.0 &   3250.0 &   2125.0 \\
# 75\%  &   3750.0 &         6062.0 &        4550.0 &   6112.0 &   5462.0 \\
# max  &  24950.0 &        30600.0 &       28950.0 &  25200.0 &  34700.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * % Errors - Bernoulli remaining value stop criteria

# %%
print(get_false_positives('conversion_rate', 'two_arms', 'sampling_beta').to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{llllll}
# \toprule
# {} & Test AB & PM wsize = 12 & PM wsize = 1 & Egreedy &   TS \\
# \midrule
# total    &     500 &           500 &          500 &     500 &  500 \\
# errors   &      38 &            24 &           38 &       3 &   40 \\
# \% errors &     7.6 &           4.8 &          7.6 &     0.6 &    8 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * regrets - pr2 stop criteria

# %%
generate_table_and_graphic('last_regrets', 'conversion_rate', 'two_arms', 'pr2', 2)
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Test AB &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &      TS \\
# \midrule
# mean &    47.34 &          24.67 &         24.57 &    53.96 &   23.94 \\
# std  &    38.44 &          22.18 &         23.24 &    42.12 &   21.14 \\
# min  &     0.70 &           1.05 &          0.17 &     0.88 &    0.66 \\
# 25\%  &    17.00 &           8.74 &          7.55 &    20.82 &    8.10 \\
# 50\%  &    40.15 &          19.39 &         18.68 &    45.91 &   18.67 \\
# 75\%  &    68.56 &          34.24 &         35.06 &    78.86 &   34.14 \\
# max  &   229.58 &         192.11 &        198.76 &   233.21 &  126.33 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * num. events - pr2. Stop criteria

# %%
generate_table_and_graphic('num_events', 'conversion_rate', 'two_arms', 'pr2', 0)
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Test AB &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &        TS \\
# \midrule
# mean &   9464.0 &        27185.0 &       25389.0 &  10792.0 &   24565.0 \\
# std  &   7687.0 &        24115.0 &       23303.0 &   8425.0 &   21798.0 \\
# min  &    130.0 &          230.0 &          20.0 &    160.0 &     750.0 \\
# 25\%  &   3385.0 &         9470.0 &        7942.0 &   4192.0 &    8545.0 \\
# 50\%  &   7990.0 &        20790.0 &       18015.0 &   9205.0 &   18285.0 \\
# 75\%  &  13695.0 &        37060.0 &       36108.0 &  15705.0 &   34340.0 \\
# max  &  45680.0 &       157550.0 &      134950.0 &  46550.0 &  173380.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * % Errors - pr stop criteria

# %%
print(get_false_positives('conversion_rate', 'two_arms', 'pr2').to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{llllll}
# \toprule
# {} & Test AB & PM wsize = 12 & PM wsize = 1 & Egreedy &   TS \\
# \midrule
# total    &     500 &           500 &          500 &     500 &  500 \\
# errors   &       1 &             1 &            4 &       5 &    4 \\
# \% errors &     0.2 &           0.2 &          0.8 &       1 &  0.8 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * sort best solutions scenario 1

# %%
print(sort_all_solutions('conversion_rate','two_arms').round(2).iloc[:5].to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{llrr}
# \toprule
# {} &     stop criteria &   mean &    std \\
# \midrule
# PM wsize = 1  &  Bern. value rem. &  10.50 &  13.52 \\
# TS            &  Bern. value rem. &  11.49 &  14.44 \\
# PM wsize = 12 &  Bern. value rem. &  12.65 &  14.63 \\
# Test AB       &  Bern. value rem. &  13.43 &  18.94 \\
# TS            &        PR2 bounds &  23.94 &  21.14 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Escenario 2: conversation time, many arms #

# %% [markdown]
# * regrets - Bernoulli remaining value stop criteria

# %%
generate_table_and_graphic('last_regrets', 'conversion_rate', 'many_arms', 'sampling_beta', 2)
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Test AB &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &      TS \\
# \midrule
# mean &  1960.02 &         194.79 &        194.56 &  1208.14 &  197.55 \\
# std  &  1331.20 &          77.18 &         74.04 &   623.98 &   83.52 \\
# min  &   207.94 &          57.45 &         71.80 &   348.27 &   70.69 \\
# 25\%  &  1044.04 &         143.25 &        142.48 &   767.95 &  142.00 \\
# 50\%  &  1671.97 &         183.51 &        182.79 &  1072.72 &  181.49 \\
# 75\%  &  2514.79 &         231.13 &        232.79 &  1521.06 &  237.43 \\
# max  &  8324.43 &         773.30 &        600.78 &  4416.81 &  805.63 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * num. events - Bernoulli remaining value. Stop criteria

# %%
generate_table_and_graphic('num_events', 'conversion_rate', 'many_arms', 'sampling_beta', 0)
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &   Test AB &  PM wsize = 12 &  PM wsize = 1 &   Egreedy &        TS \\
# \midrule
# mean &  126450.0 &        61127.0 &       60639.0 &   87840.0 &   63312.0 \\
# std  &   85897.0 &        27911.0 &       28191.0 &   48294.0 &   32726.0 \\
# min  &   13500.0 &         9000.0 &       13500.0 &   22500.0 &   13500.0 \\
# 25\%  &   67500.0 &        40500.0 &       40500.0 &   54000.0 &   40500.0 \\
# 50\%  &  108000.0 &        54000.0 &       58500.0 &   76500.0 &   54000.0 \\
# 75\%  &  162000.0 &        76785.0 &       76500.0 &  112500.0 &   81000.0 \\
# max  &  536900.0 &       191760.0 &      220140.0 &  335700.0 &  246420.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * % Errors - Bernoulli remaining value stop criteria

# %%
print(get_false_positives('conversion_rate', 'many_arms', 'sampling_beta').to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{llllll}
# \toprule
# {} & Test AB & PM wsize = 12 & PM wsize = 1 & Egreedy &   TS \\
# \midrule
# total    &     500 &           500 &          500 &     500 &  500 \\
# errors   &       1 &             3 &            0 &       1 &    2 \\
# \% errors &     0.2 &           0.6 &            0 &     0.2 &  0.4 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * regrets - pr2 value stop criteria

# %%
generate_table_and_graphic('last_regrets', 'conversion_rate', 'many_arms', 'pr2', 2)
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &   Test AB &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &      TS \\
# \midrule
# mean &   3324.49 &         220.43 &        218.13 &  1732.98 &  220.56 \\
# std  &   2405.12 &          94.55 &         81.07 &  1030.26 &   89.98 \\
# min  &    200.09 &          58.69 &         80.39 &   134.26 &   66.85 \\
# 25\%  &   1416.52 &         162.86 &        156.92 &   924.21 &  154.38 \\
# 50\%  &   2616.04 &         210.37 &        209.81 &  1489.23 &  203.34 \\
# 75\%  &   4711.06 &         261.33 &        266.59 &  2309.08 &  266.41 \\
# max  &  12666.03 &        1298.66 &        602.93 &  6006.43 &  805.39 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * num. events - pr2 Stop criteria

# %%
generate_table_and_graphic('num_events', 'conversion_rate', 'many_arms', 'pr2', 0)
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &   Test AB &  PM wsize = 12 &  PM wsize = 1 &   Egreedy &        TS \\
# \midrule
# mean &  214478.0 &       105706.0 &      105112.0 &  128500.0 &  105939.0 \\
# std  &  155161.0 &        64169.0 &       68598.0 &   79720.0 &   73436.0 \\
# min  &   12980.0 &         9080.0 &       11260.0 &    8620.0 &   10060.0 \\
# 25\%  &   91292.0 &        60118.0 &       55660.0 &   65880.0 &   56062.0 \\
# 50\%  &  168390.0 &        91980.0 &       87360.0 &  109885.0 &   86930.0 \\
# 75\%  &  304070.0 &       133525.0 &      137802.0 &  173092.0 &  134470.0 \\
# max  &  816800.0 &       451440.0 &      432180.0 &  459060.0 &  463680.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * % Errors - pr2 value stop criteria

# %%
print(get_false_positives('conversion_rate', 'many_arms', 'pr2').to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{llllll}
# \toprule
# {} & Test AB & PM wsize = 12 & PM wsize = 1 & Egreedy &   TS \\
# \midrule
# total    &     500 &           500 &          500 &     500 &  500 \\
# errors   &       0 &             2 &            0 &       1 &    2 \\
# \% errors &       0 &           0.4 &            0 &     0.2 &  0.4 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * sort best solutions scenario 2

# %%
print(sort_all_solutions('conversion_rate','many_arms').round(2).iloc[:5].to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{llrr}
# \toprule
# {} &     stop criteria &    mean &    std \\
# \midrule
# PM wsize = 1  &  Bern. value rem. &  194.56 &  74.04 \\
# PM wsize = 12 &  Bern. value rem. &  194.79 &  77.18 \\
# TS            &  Bern. value rem. &  197.55 &  83.52 \\
# PM wsize = 1  &        PR2 bounds &  218.13 &  81.07 \\
# PM wsize = 12 &        PR2 bounds &  220.43 &  94.55 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Escenario 3: Navigation time, two arms #

# %% [markdown]
# * regrets - PR2 remaining value stop criteria

# %%
generate_table_and_graphic('last_regrets', 'navigation_time', 'two_arms', 'sampling_beta', 2)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &  Test AB &     PR3 &     PR2 \\
# \midrule
# mean &          23.30 &         20.58 &    36.07 &    31.11 &   19.88 &   22.14 \\
# std  &          19.60 &         19.60 &    23.89 &    27.56 &   18.22 &   20.18 \\
# min  &           1.51 &          0.23 &    15.10 &     0.35 &    0.15 &    0.35 \\
# 25\%  &           9.02 &          6.76 &    17.10 &    10.79 &    6.88 &    7.67 \\
# 50\%  &          17.82 &         14.68 &    28.33 &    24.25 &   14.53 &   15.84 \\
# 75\%  &          31.88 &         28.16 &    45.77 &    43.84 &   27.49 &   31.99 \\
# max  &         113.31 &        109.53 &   211.53 &   156.77 &  112.63 &  118.26 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * num. events - PR2 remaining value. Stop criteria

# %%
generate_table_and_graphic('num_events', 'navigation_time', 'two_arms', 'sampling_beta', 0)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &  Test AB &      PR3 &      PR2 \\
# \midrule
# mean &         6364.0 &        5568.0 &   4786.0 &   4132.0 &   6905.0 &   6081.0 \\
# std  &         5077.0 &        4846.0 &   3168.0 &   3662.0 &   6297.0 &   4909.0 \\
# min  &          250.0 &          50.0 &   2050.0 &     50.0 &     50.0 &    100.0 \\
# 25\%  &         2538.0 &        2000.0 &   2250.0 &   1400.0 &   2150.0 &   2388.0 \\
# 50\%  &         5300.0 &        4250.0 &   3725.0 &   3200.0 &   5075.0 &   5125.0 \\
# 75\%  &         8912.0 &        7738.0 &   6025.0 &   5812.0 &  10062.0 &   9050.0 \\
# max  &        29450.0 &       27150.0 &  28000.0 &  20750.0 &  39400.0 &  30150.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * % Errors - PR2 remaining value stop criteria

# %%
print(get_false_positives('navigation_time', 'two_arms', 'sampling_beta').to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{lllllll}
# \toprule
# {} & PM wsize = 12 & PM wsize = 1 & Egreedy & Test AB &  PR3 &  PR2 \\
# \midrule
# total    &           500 &          500 &     500 &     500 &  500 &  500 \\
# errors   &             2 &            7 &       0 &       4 &    6 &    4 \\
# \% errors &           0.4 &          1.4 &       0 &     0.8 &  1.2 &  0.8 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * regrets - PR3 remaining value stop criteria

# %%
generate_table_and_graphic('last_regrets', 'navigation_time', 'two_arms', 'sampling_beta_PR3', 2)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &  Test AB &     PR3 &     PR2 \\
# \midrule
# mean &          20.53 &         18.05 &    29.85 &    24.87 &   17.51 &   19.23 \\
# std  &          17.23 &         17.00 &    18.12 &    21.29 &   16.16 &   17.66 \\
# min  &           1.51 &          0.23 &    15.10 &     0.35 &    0.15 &    0.15 \\
# 25\%  &           8.23 &          6.43 &    16.32 &     9.98 &    6.55 &    6.51 \\
# 50\%  &          15.83 &         13.40 &    23.55 &    19.36 &   12.80 &   14.03 \\
# 75\%  &          27.90 &         23.24 &    36.91 &    33.18 &   22.85 &   26.96 \\
# max  &         105.55 &        105.31 &   129.05 &   140.40 &  112.29 &  115.76 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * num. events - PR3 remaining value. Stop criteria

# %%
generate_table_and_graphic('num_events', 'navigation_time', 'two_arms', 'sampling_beta_PR3', 0)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &  Test AB &      PR3 &      PR2 \\
# \midrule
# mean &         4838.0 &        4260.0 &   3964.0 &   3303.0 &   4770.0 &   4502.0 \\
# std  &         3568.0 &        3251.0 &   2406.0 &   2829.0 &   3620.0 &   3174.0 \\
# min  &          250.0 &          50.0 &   2050.0 &     50.0 &     50.0 &     50.0 \\
# 25\%  &         2250.0 &        1850.0 &   2150.0 &   1300.0 &   2000.0 &   2050.0 \\
# 50\%  &         4150.0 &        3650.0 &   3125.0 &   2600.0 &   3975.0 &   3750.0 \\
# 75\%  &         6362.0 &        5850.0 &   4950.0 &   4450.0 &   6712.0 &   6512.0 \\
# max  &        24750.0 &       16550.0 &  17050.0 &  18750.0 &  19850.0 &  19750.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * % Errors - PR3 remaining value stop criteria

# %%
print(get_false_positives('navigation_time', 'two_arms', 'sampling_beta_PR3').to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{lllllll}
# \toprule
# {} & PM wsize = 12 & PM wsize = 1 & Egreedy & Test AB &  PR3 &  PR2 \\
# \midrule
# total    &           500 &          500 &     500 &     500 &  500 &  500 \\
# errors   &             4 &            8 &       0 &       5 &    6 &    5 \\
# \% errors &           0.8 &          1.6 &       0 &       1 &  1.2 &    1 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * regrets - PR2 bound stop criteria

# %%
generate_table_and_graphic('last_regrets', 'navigation_time', 'two_arms', 'pr2', 2)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &  Test AB &     PR3 &     PR2 \\
# \midrule
# mean &          41.78 &         41.82 &    96.28 &    95.40 &   35.21 &   40.97 \\
# std  &          25.14 &         26.93 &    50.73 &    51.00 &   21.85 &   26.89 \\
# min  &           1.94 &          0.47 &     3.75 &     3.45 &    1.61 &    0.90 \\
# 25\%  &          22.52 &         22.14 &    59.87 &    57.42 &   19.53 &   21.81 \\
# 50\%  &          37.46 &         34.98 &    86.53 &    88.66 &   31.18 &   35.01 \\
# 75\%  &          55.47 &         57.60 &   129.45 &   124.44 &   47.72 &   56.14 \\
# max  &         137.98 &        162.59 &   316.60 &   257.63 &  120.98 &  236.92 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * num. events - PR2 conf Stop criteria

# %%
generate_table_and_graphic('num_events', 'navigation_time', 'two_arms', 'pr2', 0)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &  Test AB &       PR3 &       PR2 \\
# \midrule
# mean &        35957.0 &       35677.0 &  12786.0 &  12673.0 &   57131.0 &   34122.0 \\
# std  &        20826.0 &       22395.0 &   6742.0 &   6765.0 &   40981.0 &   20371.0 \\
# min  &          740.0 &         600.0 &    520.0 &    490.0 &    1870.0 &     870.0 \\
# 25\%  &        21035.0 &       20465.0 &   7940.0 &   7615.0 &   26385.0 &   18722.0 \\
# 50\%  &        31705.0 &       30110.0 &  11555.0 &  11730.0 &   49550.0 &   29965.0 \\
# 75\%  &        48770.0 &       47048.0 &  17155.0 &  16568.0 &   79965.0 &   45222.0 \\
# max  &       163430.0 &      121980.0 &  42110.0 &  33980.0 &  263060.0 &  122360.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * % Errors - PR2 conf stop criteria

# %%
print(get_false_positives('navigation_time', 'two_arms', 'pr2').to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{lllllll}
# \toprule
# {} & PM wsize = 12 & PM wsize = 1 & Egreedy & Test AB &  PR3 &  PR2 \\
# \midrule
# total    &           500 &          500 &     500 &     500 &  500 &  500 \\
# errors   &             0 &            0 &       0 &       0 &    0 &    0 \\
# \% errors &             0 &            0 &       0 &       0 &    0 &    0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * regrets - PR3 conf stop criteria

# %%
generate_table_and_graphic('last_regrets', 'navigation_time', 'two_arms', 'pr3', 2)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &  Test AB &     PR3 &     PR2 \\
# \midrule
# mean &          32.82 &         32.38 &    58.76 &    57.50 &   27.96 &   31.75 \\
# std  &          21.24 &         22.22 &    32.75 &    33.80 &   18.73 &   23.50 \\
# min  &           1.91 &          0.47 &     3.55 &     3.45 &    1.27 &    0.89 \\
# 25\%  &          17.64 &         16.51 &    35.02 &    32.48 &   14.72 &   15.90 \\
# 50\%  &          27.85 &         26.81 &    53.31 &    50.53 &   22.79 &   26.14 \\
# 75\%  &          44.42 &         42.65 &    78.54 &    76.78 &   37.85 &   41.15 \\
# max  &         120.69 &        122.45 &   234.29 &   177.09 &  115.34 &  235.91 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * num. events - PR3 conf. Stop criteria

# %%
generate_table_and_graphic('num_events', 'navigation_time', 'two_arms', 'pr3', 0)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &  Test AB &      PR3 &      PR2 \\
# \midrule
# mean &        15617.0 &       15177.0 &   7802.0 &   7638.0 &  19051.0 &  14605.0 \\
# std  &         8243.0 &        8463.0 &   4351.0 &   4491.0 &  11372.0 &   7879.0 \\
# min  &          510.0 &         600.0 &    490.0 &    490.0 &    940.0 &    830.0 \\
# 25\%  &         9588.0 &        9690.0 &   4658.0 &   4318.0 &  10510.0 &   8765.0 \\
# 50\%  &        14025.0 &       13305.0 &   7130.0 &   6705.0 &  17050.0 &  13055.0 \\
# 75\%  &        20352.0 &       18860.0 &  10420.0 &  10215.0 &  25788.0 &  18622.0 \\
# max  &        49390.0 &       62650.0 &  31180.0 &  23720.0 &  77020.0 &  45170.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * % Errors - PR3 conf stop criteria

# %%
print(get_false_positives('navigation_time', 'two_arms', 'pr3').to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{lllllll}
# \toprule
# {} & PM wsize = 12 & PM wsize = 1 & Egreedy & Test AB &  PR3 &  PR2 \\
# \midrule
# total    &           500 &          500 &     500 &     500 &  500 &  500 \\
# errors   &             0 &            0 &       0 &       0 &    0 &    0 \\
# \% errors &             0 &            0 &       0 &       0 &    0 &    0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * sort best solutions scenario 3

# %%
print(sort_all_solutions('navigation_time','two_arms').round(2).iloc[:5].to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{llrr}
# \toprule
# {} &   stop criteria &   mean &    std \\
# \midrule
# PR3           &  PR3 value rem. &  17.51 &  16.16 \\
# PM wsize = 1  &  PR3 value rem. &  18.05 &  17.00 \\
# PR2           &  PR3 value rem. &  19.23 &  17.66 \\
# PR3           &  PR2 value rem. &  19.88 &  18.22 \\
# PM wsize = 12 &  PR3 value rem. &  20.53 &  17.23 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Escenario 4: Navigation time, Many arms #

# %% [markdown]
# * regrets - PR2 remaining value stop criteria

# %%
generate_table_and_graphic('last_regrets', 'navigation_time', 'many_arms', 'sampling_beta', 2)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &  Test AB &     PR3 &     PR2 \\
# \midrule
# mean &         428.11 &        419.93 &   725.43 &   947.35 &  395.03 &  423.06 \\
# std  &          96.67 &         97.94 &   241.90 &   357.92 &   71.45 &   83.04 \\
# min  &         156.38 &        188.93 &   234.95 &   183.23 &  212.73 &  209.08 \\
# 25\%  &         362.97 &        352.14 &   520.26 &   671.62 &  341.81 &  367.76 \\
# 50\%  &         419.60 &        405.44 &   683.02 &   913.20 &  388.04 &  416.28 \\
# 75\%  &         484.65 &        481.78 &   894.56 &  1154.72 &  441.13 &  471.08 \\
# max  &         808.77 &        828.59 &  1507.29 &  2254.41 &  665.67 &  706.26 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * num. events - PR2 remaining value. Stop criteria

# %%
generate_table_and_graphic('num_events', 'navigation_time', 'many_arms', 'sampling_beta', 0)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &   Egreedy &   Test AB &       PR3 &       PR2 \\
# \midrule
# mean &        88687.0 &       87989.0 &   57547.0 &   69888.0 &  207594.0 &   91691.0 \\
# std  &        23677.0 &       22364.0 &   19408.0 &   26399.0 &   78302.0 &   22647.0 \\
# min  &        31430.0 &       27000.0 &   18000.0 &   13500.0 &   45000.0 &   36000.0 \\
# 25\%  &        72222.0 &       73185.0 &   41088.0 &   49500.0 &  149905.0 &   75898.0 \\
# 50\%  &        86875.0 &       86530.0 &   54000.0 &   67475.0 &  201750.0 &   89875.0 \\
# 75\%  &       102670.0 &      100930.0 &   71415.0 &   85185.0 &  253658.0 &  106348.0 \\
# max  &       193680.0 &      172900.0 &  119790.0 &  166230.0 &  506970.0 &  175200.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * % Errors - PR2 remaining value stop criteria

# %%
print(get_false_positives('navigation_time', 'many_arms', 'sampling_beta').to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{lllllll}
# \toprule
# {} & PM wsize = 12 & PM wsize = 1 & Egreedy & Test AB &  PR3 &  PR2 \\
# \midrule
# total    &           500 &          500 &     500 &     500 &  500 &  500 \\
# errors   &             0 &            0 &       0 &       0 &    0 &    0 \\
# \% errors &             0 &            0 &       0 &       0 &    0 &    0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * regrets - PR3 remaining value stop criteria

# %%
generate_table_and_graphic('last_regrets', 'navigation_time', 'many_arms', 'sampling_beta_PR3', 2)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &  Test AB &     PR3 &     PR2 \\
# \midrule
# mean &         349.41 &        344.55 &   531.66 &   683.78 &  314.40 &  343.00 \\
# std  &          88.92 &         92.92 &   186.08 &   285.55 &   65.79 &   77.13 \\
# min  &         145.94 &        162.50 &   177.90 &   182.25 &  172.80 &  177.18 \\
# 25\%  &         289.86 &        279.59 &   401.40 &   487.93 &  268.63 &  290.73 \\
# 50\%  &         338.13 &        335.19 &   513.53 &   611.91 &  306.27 &  333.48 \\
# 75\%  &         400.35 &        390.36 &   641.06 &   834.55 &  347.77 &  385.92 \\
# max  &         746.18 &        812.49 &  1189.84 &  1776.68 &  594.02 &  663.96 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * num. events - PR3 remaining value. Stop criteria

# %%
generate_table_and_graphic('num_events', 'navigation_time', 'many_arms', 'sampling_beta_PR3', 0)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &   Test AB &       PR3 &      PR2 \\
# \midrule
# mean &        51626.0 &       51566.0 &  41856.0 &   50443.0 &   71610.0 &  51963.0 \\
# std  &        12974.0 &       13183.0 &  14858.0 &   21063.0 &   20077.0 &  12284.0 \\
# min  &        18000.0 &       18000.0 &  13500.0 &   13500.0 &   22500.0 &  27000.0 \\
# 25\%  &        43068.0 &       43192.0 &  31500.0 &   36000.0 &   56802.0 &  42065.0 \\
# 50\%  &        50855.0 &       50910.0 &  40500.0 &   45050.0 &   68970.0 &  51665.0 \\
# 75\%  &        59865.0 &       59625.0 &  50685.0 &   61518.0 &   85075.0 &  60495.0 \\
# max  &        97380.0 &       91320.0 &  91850.0 &  131120.0 &  152950.0 &  95430.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * % Errors - PR3 remaining value stop criteria

# %%
print(get_false_positives('navigation_time', 'many_arms', 'sampling_beta_PR3').to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{lllllll}
# \toprule
# {} & PM wsize = 12 & PM wsize = 1 & Egreedy & Test AB &  PR3 &  PR2 \\
# \midrule
# total    &           500 &          500 &     500 &     500 &  500 &  500 \\
# errors   &             0 &            0 &       0 &       0 &    0 &    0 \\
# \% errors &             0 &            0 &       0 &       0 &    0 &    0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * regrets - PR2 bound stop criteria

# %%
generate_table_and_graphic('last_regrets', 'navigation_time', 'many_arms', 'pr2', 2)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &  Test AB &     PR3 &     PR2 \\
# \midrule
# mean &         445.88 &        436.01 &   957.14 &  1407.13 &  378.91 &  433.31 \\
# std  &         101.07 &        101.03 &   281.72 &   471.27 &   71.88 &   88.91 \\
# min  &         167.87 &        179.51 &   221.51 &   206.53 &  211.24 &  226.98 \\
# 25\%  &         376.28 &        364.47 &   769.62 &  1086.32 &  327.35 &  372.27 \\
# 50\%  &         435.63 &        426.39 &   947.62 &  1336.47 &  371.78 &  428.67 \\
# 75\%  &         503.90 &        496.94 &  1136.66 &  1655.13 &  420.22 &  484.49 \\
# max  &         813.74 &        848.59 &  1916.46 &  3012.83 &  654.53 &  731.48 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * num. events - PR2 conf Stop criteria

# %%
generate_table_and_graphic('num_events', 'navigation_time', 'many_arms', 'pr2', 0)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &   Egreedy &   Test AB &       PR3 &       PR2 \\
# \midrule
# mean &       101205.0 &       99409.0 &   76310.0 &  103809.0 &  169198.0 &   99834.0 \\
# std  &        26714.0 &       25173.0 &   22647.0 &   34765.0 &   56442.0 &   26484.0 \\
# min  &        42380.0 &       38200.0 &   16880.0 &   15240.0 &   48240.0 &   45350.0 \\
# 25\%  &        82818.0 &       81772.0 &   61255.0 &   80168.0 &  127968.0 &   82195.0 \\
# 50\%  &       100060.0 &       96515.0 &   75580.0 &   98650.0 &  163450.0 &   96610.0 \\
# 75\%  &       115128.0 &      116872.0 &   90740.0 &  122220.0 &  203262.0 &  114398.0 \\
# max  &       196680.0 &      175000.0 &  154300.0 &  222150.0 &  423820.0 &  211400.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * % Errors - PR2 conf stop criteria

# %%
print(get_false_positives('navigation_time', 'many_arms', 'pr2').to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{lllllll}
# \toprule
# {} & PM wsize = 12 & PM wsize = 1 & Egreedy & Test AB &  PR3 &  PR2 \\
# \midrule
# total    &           500 &          500 &     500 &     500 &  500 &  500 \\
# errors   &             0 &            0 &       0 &       0 &    0 &    0 \\
# \% errors &             0 &            0 &       0 &       0 &    0 &    0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * regrets - PR3 conf stop criteria

# %%
generate_table_and_graphic('last_regrets', 'navigation_time', 'many_arms', 'pr3', 2)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &  Egreedy &  Test AB &     PR3 &     PR2 \\
# \midrule
# mean &         344.19 &        336.18 &   627.74 &   913.55 &  297.88 &  331.95 \\
# std  &          98.32 &         99.07 &   209.40 &   360.00 &   72.73 &   84.50 \\
# min  &         135.76 &        132.71 &   180.63 &   173.19 &  150.12 &  130.03 \\
# 25\%  &         273.66 &        266.83 &   467.87 &   655.29 &  250.63 &  271.05 \\
# 50\%  &         334.61 &        325.60 &   616.44 &   859.25 &  289.49 &  321.90 \\
# 75\%  &         395.12 &        383.64 &   765.26 &  1112.62 &  339.08 &  375.92 \\
# max  &         754.53 &        819.06 &  1389.03 &  2276.75 &  594.53 &  670.42 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * num. events - PR3 conf. Stop criteria

# %%
generate_table_and_graphic('num_events', 'navigation_time', 'many_arms', 'pr3', 0)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  PM wsize = 12 &  PM wsize = 1 &   Egreedy &   Test AB &       PR3 &      PR2 \\
# \midrule
# mean &        49327.0 &       48151.0 &   49635.0 &   67394.0 &   58375.0 &  47569.0 \\
# std  &        13553.0 &       12881.0 &   16761.0 &   26554.0 &   17245.0 &  11841.0 \\
# min  &        19370.0 &       18300.0 &   13590.0 &   12740.0 &   25290.0 &  21630.0 \\
# 25\%  &        39365.0 &       39170.0 &   36818.0 &   48415.0 &   45288.0 &  39170.0 \\
# 50\%  &        48550.0 &       47080.0 &   48795.0 &   63360.0 &   55945.0 &  46370.0 \\
# 75\%  &        57392.0 &       56282.0 &   60920.0 &   82100.0 &   68310.0 &  55032.0 \\
# max  &       103830.0 &       91840.0 &  111400.0 &  168050.0 &  115490.0 &  98910.0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * % Errors - PR3 conf stop criteria

# %%
print(get_false_positives('navigation_time', 'many_arms', 'pr3').to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{lllllll}
# \toprule
# {} & PM wsize = 12 & PM wsize = 1 & Egreedy & Test AB &  PR3 &  PR2 \\
# \midrule
# total    &           500 &          500 &     500 &     500 &  500 &  500 \\
# errors   &             0 &            0 &       0 &       0 &    0 &    0 \\
# \% errors &             0 &            0 &       0 &       0 &    0 &    0 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# * sort best solutions scenario 3

# %%
print(sort_all_solutions('navigation_time','many_arms').round(2).iloc[:5].to_latex(encoding='utf-8'))
# Out:
# \begin{tabular}{llrr}
# \toprule
# {} &   stop criteria &    mean &    std \\
# \midrule
# PR3          &      PR3 bounds &  297.88 &  72.73 \\
# PR3          &  PR3 value rem. &  314.40 &  65.79 \\
# PR2          &      PR3 bounds &  331.95 &  84.50 \\
# PM wsize = 1 &      PR3 bounds &  336.18 &  99.07 \\
# PR2          &  PR3 value rem. &  343.00 &  77.13 \\
# \bottomrule
# \end{tabular}
